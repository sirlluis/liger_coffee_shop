# %%
import pandas as pd
from pathlib import Path

# %%
DATA_PATH=Path().cwd()/"data"/"raw"
print(DATA_PATH)
# Out:
# c:\Users\Mi PC\Desktop\liger_coffee_shop\data\raw

# %%
tablas = {
    "branches": None,
    "ingredients": None,
    "inventory_movements": None,
    "order_items": None,
    "orders": None,
    "products": None,
    "purchases": None,
    "recipes": None
}

for item in tablas:
    df = pd.read_csv(f"{DATA_PATH}/{item}.csv")
    column_names = df.columns.tolist()
    tablas[item] = column_names
# Out:
# C:\Users\Mi PC\AppData\Local\Temp\ipykernel_8508\215503434.py:13: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{DATA_PATH}/{item}.csv")

# %%
tablas
# Out:
# {'branches': ['branch_id', 'name'],
#  'ingredients': ['ingredient_id',
#   'name',
#   'unit_of_measure',
#   'unit_cost',
#   'category'],
#  'inventory_movements': ['movement_id',
#   'ingredient_id',
#   'movement_type',
#   'quantity',
#   'order_item_id',
#   'purchase_id',
#   'occurred_at',
#   'notes'],
#  'order_items': ['order_item_id',
#   'order_id',
#   'product_id',
#   'quantity',
#   'sale_price'],
#  'orders': ['order_id',
#   'branch_id',
#   'created_at',
#   'in_or_out',
#   'payment_method'],
#  'products': ['product_id', 'name', 'category', 'unit_price'],
#  'purchases': ['purchase_id',
#   'ingredient_id',
#   'branch_id',
#   'quantity',
#   'unit_cost_real',
#   'supplier_name',
#   'purchased_at'],
#  'recipes': ['recipe_id', 'product_id', 'ingredient_id', 'quantity_required']}
